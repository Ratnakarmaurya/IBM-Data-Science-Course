# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Ratnakar Maurya**
# Aspiring Data Scientist

# %% [markdown]
# _I am interested in data science because data is beautiful,i cherish the way numbers tell stories,story telling is the most amazing feature of a Data Scientist i would like to Develop, futhermore i speak Fluent Python which gives me a direction in Data Science._

# %% [markdown]
# ### Printing Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# #### Skills of Data Scientist's
# 1.Data Analytics
# - Pandas
# - Numpy
# - dusk(optional)
# ***
# 2.Data Visualization
# - Matplotlib
# - Seaborn
# - plotly
# ***
# 3.Machine Learning
# - All Algorithm
# - Deep Learning
# ***
# 4.Python
# - Core
# - Advance
# ***
# 5.SQL
# ___
# Python Logo:
# ![alt text](http://pluspng.com/img-png/python-logo-png-python-logo-png-image-png-image-200.png)
